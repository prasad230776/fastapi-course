# %% [markdown]
# # Python Data Structures - Practice Exercises
# Apply lists, tuples, sets, dictionaries, and deques to solve these challenges.

# %% [markdown]
# ### Exercise 1: String Slicing and Formatting
# 1. Define a variable `text = "FastAPI Course - Level Up"`.
# 2. Extract the word `"FastAPI"` using slicing.
# 3. Reverse the entire string `text` using slicing.
# 4. Format a message: `"Course name: FastAPI (Reversed: pU leveL - esruoC IpatsaF)"` using f-strings.

# %%
# Write your code below

# %% [markdown]
# ### Exercise 2: List Operations and Comprehensions
# 1. Create a list of numbers from 1 to 10.
# 2. Write a list comprehension to create a list of the cubes of all odd numbers in that list.
# 3. Print the resulting list.

# %%
# Write your code below

# %% [markdown]
# ### Exercise 3: Tuple Packing, Unpacking, and Singletons
# 1. Define a function or code block that represents a coordinates point `(45.5, -122.6)` as a tuple.
# 2. Unpack this tuple into `latitude` and `longitude` variables.
# 3. Create a single-element tuple containing only the string `"Origin"` and print its type to verify it is a tuple.

# %%
# Write your code below

# %% [markdown]
# ### Exercise 4: Set Membership & Deduplication
# 1. Given the list `items = ["apple", "banana", "apple", "cherry", "banana"]`.
# 2. Remove duplicates by converting it to a set.
# 3. Find the union and intersection of this set with `other_fruits = {"cherry", "date", "fig"}`.

# %%
# Write your code below

# %% [markdown]
# ### Exercise 5: Dictionary Manipulation and Comprehension
# 1. Create a dictionary storing three items and their prices (e.g., `"laptop": 1200`, `"mouse": 20`, `"keyboard": 80`).
# 2. Retrieve the price of a `"headphone"` using `.get()`, defaulting to `50` if not found.
# 3. Create a new dictionary from the original price list, containing only items that cost more than `50` using dictionary comprehension.

# %%
# Write your code below

# %% [markdown]
# ### Exercise 6: Deque Rotation and Queue Simulation
# 1. Initialize a `deque` with values `[1, 2, 3, 4, 5]`.
# 2. Append `6` to the right, and `0` to the left.
# 3. Rotate the deque by `2` steps to the right.
# 4. Pop one item from the left and print the final state of the deque.

# %%
# Write your code below
