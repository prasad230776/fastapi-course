# %% [markdown]
# # Modules and Packages - Practice Exercises
# Practice working with custom modules, standard library modules (os, datetime, uuid, json, pathlib), and third-party HTTP requests.

# %% [markdown]
# ### Exercise 1: Custom Module Creation and Import
# 1. Create a Python module named `geometry.py` programmatically containing a function `circle_area(radius)` that computes the area of a circle ($\pi r^2$).
# 2. Import it and calculate the area of a circle with radius 5.

# %%
# Write your code below

# %% [markdown]
# ### Exercise 2: Pathlib File Navigator
# 1. Use `pathlib.Path` to create a new subdirectory named `test_exercise_dir`.
# 2. Create a file inside that directory named `notes.txt` containing the text `"Learning Python modules!"`.
# 3. Read the text from the file using `read_text()` and print it.
# 4. Clean up by deleting the file and directory.

# %%
# Write your code below

# %% [markdown]
# ### Exercise 3: OS Environment Variables
# 1. Set an environment variable named `APP_ENV` to `"production"` using `os.environ`.
# 2. Retrieve and print it using `os.environ.get()` with a default value of `"development"`.

# %%
# Write your code below

# %% [markdown]
# ### Exercise 4: Date Calculations
# 1. Import `datetime`.
# 2. Calculate the date exactly 10 days from today.
# 3. Format the result as `"YYYY-MM-DD"` and print it.

# %%
# Write your code below

# %% [markdown]
# ### Exercise 5: JSON Formatting and Parsing
# 1. Define a list of user dictionaries, each having keys `"id"`, `"name"`, and `"email"`.
# 2. Serialize this list into a JSON formatted string with an indentation of 4 spaces.
# 3. Print the JSON string, and then parse it back into a Python list to print the length of the list.

# %%
# Write your code below

# %% [markdown]
# ### Exercise 6: API Fetch and Filter
# 1. Make a GET request to `https://jsonplaceholder.typicode.com/users` using `requests`.
# 2. Loop through the returned list of users.
# 3. Print the name and email of any user whose username contains the letter `"a"` or `"A"`.

# %%
# Write your code below
