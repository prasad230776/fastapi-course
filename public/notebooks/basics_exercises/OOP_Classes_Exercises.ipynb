# %% [markdown]
# # Classes and OOP - Practice Exercises
# Apply class definitions, inheritance, encapsulation, property setters, abstract interfaces, and introspection to solve these challenges.

# %% [markdown]
# ### Exercise 1: Basic Class & Methods
# 1. Define a class `Car` with instance attributes `make`, `model`, and `year`.
# 2. Add an instance method `description()` that returns `"Make Model (Year)"`.
# 3. Add a class attribute `total_cars = 0` and increment it inside `__init__` each time a new car is created.

# %%
# Write your code below

# %% [markdown]
# ### Exercise 2: Class & Static Methods
# 1. Update the `Car` class or create a new class `Book`.
# 2. Add a `@classmethod` named `from_string(cls, book_info)` that splits a comma-separated string `"Title, Author"` and returns a class instance.
# 3. Add a `@staticmethod` named `is_valid_title(title)` that returns True if the title is longer than 2 characters.

# %%
# Write your code below

# %% [markdown]
# ### Exercise 3: Inheritance and Method Overriding
# 1. Define a parent class `Employee` with an attribute `name` and a method `get_salary()` returning `50000`.
# 2. Define a child class `Manager` inheriting from `Employee` with an additional attribute `department`.
# 3. Override `get_salary()` in `Manager` to return `80000`.

# %%
# Write your code below

# %% [markdown]
# ### Exercise 4: Encapsulation & Properties
# 1. Create a `BankAccount` class with a private field `__balance`.
# 2. Add a `@property` getter for `balance`.
# 3. Add a `@balance.setter` that verifies the set balance is positive and doesn't allow setting values directly if they are negative.

# %%
# Write your code below

# %% [markdown]
# ### Exercise 5: Abstract Base Class Implementation
# 1. Import `ABC` and `abstractmethod` from `abc`.
# 2. Create an abstract class `NotificationSender` with an abstract method `send(message: str, recipient: str)`.
# 3. Implement a subclass `EmailSender` implementing the `send` method by printing a formatted email string.

# %%
# Write your code below

# %% [markdown]
# ### Exercise 6: Introspection Challenge
# 1. Create any class with type annotations and some instance variables.
# 2. Write a function `print_metadata(obj)` that takes an object instance, prints its annotations, and prints the instance variables namespace dictionary (`__dict__`).

# %%
# Write your code below
