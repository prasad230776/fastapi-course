# %% [markdown]
# # Asynchronous Programming - Practice Exercises
# Apply async/await, coroutine definition, and concurrency mechanics to complete these challenges.

# %% [markdown]
# ### Exercise 1: Simulate File Downloader
# 1. Write an async function `download_file(file_name, size_mb)`.
# 2. Print `"Downloading file_name (size_mb MB)..."`.
# 3. Sleep asynchronously for 1.5 seconds.
# 4. Print `"Downloaded file_name!"` and return a dictionary like `{"filename": file_name, "status": "success"}`.
# 5. Run and await this function in a code cell.

# %%
# Write your code below

# %% [markdown]
# ### Exercise 2: Concurrent Batch Downloader
# 1. Define a list of three filenames to download.
# 2. Trigger all three downloads concurrently using `asyncio.gather()`.
# 3. Print the results list and check the execution time.

# %%
# Write your code below
