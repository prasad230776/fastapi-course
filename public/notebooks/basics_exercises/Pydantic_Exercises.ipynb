# %% [markdown]
# # Data Validation with Pydantic - Practice Exercises
# Validate, serialize, and constrain complex data formats using Pydantic models.

# %% [markdown]
# ### Exercise 1: Basic Schema Validation & Coercion
# 1. Define a Pydantic `Student` model with attributes: `id` (int), `name` (str), and `gpa` (float).
# 2. Create an instance with coerced values: `id="42"`, `name="Bob"`, `gpa="3.75"`.
# 3. Catch any `ValidationError` and print it if we pass `gpa="awesome"`.

# %%
# Write your code below

# %% [markdown]
# ### Exercise 2: Field Range Constraints
# 1. Create a `Movie` schema with attributes:
#    - `title`: string length between 1 and 100.
#    - `rating`: float between 0.0 and 10.0.
#    - `release_year`: integer greater than or equal to 1888.
# 2. Test instantiating it with bad values and catch/print the validation errors.

# %%
# Write your code below

# %% [markdown]
# ### Exercise 3: Custom Field Validators
# 1. Define a `Registration` schema requiring `username` and `email`.
# 2. Add a custom `@field_validator("email")` to verify the email ends with either `".com"`, `".org"`, or `".net"`.
# 3. Test it with valid and invalid emails, catching errors where appropriate.

# %%
# Write your code below

# %% [markdown]
# ### Exercise 4: Nested Transaction Models and Dumps
# 1. Define a `TransactionItem` with `item_id` (str) and `price` (float).
# 2. Define a `Transaction` with `txn_id` (str) and a list of `items` (`list[TransactionItem]`).
# 3. Create an instance containing three items.
# 4. Serialize the transaction into a raw dictionary, and also into a JSON string.

# %%
# Write your code below
