# %% [markdown]
# # Type Hinting - Practice Exercises
# Test your understanding of type annotations on variables, lists, dictionaries, tuples, unions, and return types.

# %% [markdown]
# ### Exercise 1: Annotating Function Signatures
# 1. Write a function `greet_user(name, age)`.
# 2. Annotate `name` as a string and `age` as an integer.
# 3. Annotate the function return type to indicate it returns a string `"Hello, Name! You are Age years old."`

# %%
# Write your code below

# %% [markdown]
# ### Exercise 2: Typed List of Dictionaries
# 1. Define a list named `database` containing dictionaries.
# 2. Annotate the type of `database` to explicitly show it is a list of dictionaries mapping strings (keys) to string/int/float values.

# %%
# Write your code below

# %% [markdown]
# ### Exercise 3: Union Value Aggregator
# 1. Write a function `process_value(val)`.
# 2. Annotate `val` to accept either an integer or float.
# 3. Annotate the return type as a float.

# %%
# Write your code below

# %% [markdown]
# ### Exercise 4: Optional Profile Field
# 1. Write a function `get_profile_link(user_id, custom_slug)`.
# 2. `user_id` should be an integer.
# 3. `custom_slug` should be an optional string defaulting to `None`.
# 4. Annotate the parameters and return type accordingly.

# %%
# Write your code below
