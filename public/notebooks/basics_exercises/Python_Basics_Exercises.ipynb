# %% [markdown]
# # Python Basics - Practice Exercises
# Test your understanding of variables, operators, and control flow in Python with these challenges.

# %% [markdown]
# ### Exercise 1: Swapping and Object Identity
# 1. Define two variables, `x = 100` and `y = 200`.
# 2. Swap their values.
# 3. Check if `x` points to the same memory object as a new variable `z = 200` using identity operators (`is` / `is not`). Print the result and explain it.

# %%
# Write your code below

# %% [markdown]
# ### Exercise 2: Safe Floating-Point Comparison
# 1. Try running `0.1 + 0.1 + 0.1 == 0.3` and see what it outputs.
# 2. Correct this check using `round()` or `math.isclose()` so it prints `True`.

# %%
# Write your code below

# %% [markdown]
# ### Exercise 3: Truthy/Falsy Check and Short-circuiting
# 1. Define a variable `username` which is an empty string.
# 2. Assign a variable `display_name` to be `username` if it's truthy, otherwise default to `"Anonymous"` using short-circuit evaluation with `or`.
# 3. Print `display_name`.

# %%
# Write your code below

# %% [markdown]
# ### Exercise 4: Division, Floor Division, Modulus, and Bitwise Shifts
# 1. Take a variable `num = 23`.
# 2. Find the result of division by 4.
# 3. Find the result of floor division by 4.
# 4. Find the remainder when divided by 4.
# 5. Double `num` twice using bitwise left shift `<<`.

# %%
# Write your code below

# %% [markdown]
# ### Exercise 5: Leap Year Calculator
# Write an if-elif-else program that checks if a given year is a leap year.
# A year is leap if it is divisible by 4, except for century years (divisible by 100), which must also be divisible by 400.

# %%
# Write your code below
year = 2024

# %% [markdown]
# ### Exercise 6: Interactive Number Filter Loop
# Write a loop that iterates through numbers from 1 to 15. For each number:
# - If it is divisible by 5, skip the iteration (use `continue`).
# - If the number is greater than 12, terminate the loop (use `break`).
# - Otherwise, print the number.

# %%
# Write your code below
