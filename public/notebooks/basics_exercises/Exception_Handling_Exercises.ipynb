# %% [markdown]
# # Exception Handling - Practice Exercises
# Practice catching multiple exceptions, resource cleanups with finally, and writing custom domain exceptions.

# %% [markdown]
# ### Exercise 1: Safe Division Function
# 1. Write a function `safe_divide(a, b)`.
# 2. Wrap division in a try block.
# 3. Catch `ZeroDivisionError` and `TypeError` exceptions, returning `None` and printing appropriate error messages.

# %%
# Write your code below

# %% [markdown]
# ### Exercise 2: File Loader with Cleanup
# 1. Write a function `read_config(filename)`.
# 2. Try to open and read the file.
# 3. Catch `FileNotFoundError`.
# 4. Use an `else` block to print success.
# 5. Use a `finally` block to guarantee printing `"File operation finished"`.

# %%
# Write your code below

# %% [markdown]
# ### Exercise 3: Input Verification and Raising Errors
# 1. Write a function `validate_username(username: str)`.
# 2. If the username is shorter than 5 characters, raise a `ValueError` with a descriptive message.
# 3. Test calling this function with valid and invalid values within a try-except block.

# %%
# Write your code below

# %% [markdown]
# ### Exercise 4: Custom User Exceptions
# 1. Define a custom exception `InvalidEmailError(Exception)` that accepts the invalid email address string as an argument.
# 2. Write a function `register_email(email)` that checks if the string contains `"@"`.
# 3. If it doesn't, raise `InvalidEmailError`.
# 4. Catch the exception and print a formatted error message.

# %%
# Write your code below
