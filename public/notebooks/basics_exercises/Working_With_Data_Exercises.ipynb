# %% [markdown]
# # Working with Data - Practice Exercises
# Apply file handling, JSON serialization/deserialization, and CSV reading/writing to solve these challenges.

# %% [markdown]
# ### Exercise 1: Uppercase Text File Filter
# 1. Write a program that reads a text file `source.txt` line-by-line.
# 2. Capitalize the content of each line.
# 3. Write the capitalized lines into a new file `destination.txt`.
# 4. Clean up any trailing space or newlines using `.strip()`.

# %%
# Write your code below

# %% [markdown]
# ### Exercise 2: Application Settings Serializer
# 1. Create a Python dictionary representing user/app configurations (e.g. theme, notifications, auto-save interval).
# 2. Write these settings to a file `settings.json` using `json.dump()` with an indentation of 4 spaces.
# 3. Read the file back using `json.load()` and print the auto-save configuration value.

# %%
# Write your code below

# %% [markdown]
# ### Exercise 3: CSV Product Inventory Dump
# 1. Define a list of products where each product is represented by a dictionary containing keys: `"id"`, `"name"`, `"price"`, `"category"`.
# 2. Use `csv.DictWriter` to save this list into a file `products.csv`.
# 3. Verify it was written successfully by opening the file and printing its raw lines.

# %%
# Write your code below

# %% [markdown]
# ### Exercise 4: Calculate Marks Average from CSV
# 1. programmatically create a CSV file `students.csv` with headings `"Name,Math,Science"` and rows `"Alice,90,85\nBob,75,80\nCharlie,88,92"`.
# 2. Use `csv.DictReader` to load this file.
# 3. Calculate and print the average math and science grade of all students.

# %%
# Write your code below
