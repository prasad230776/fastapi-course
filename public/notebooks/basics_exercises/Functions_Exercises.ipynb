# %% [markdown]
# # Python Functions - Practice Exercises
# Test your understanding of scopes, closures, lambdas, generators, decorators, *args/**kwargs, and functional programming.

# %% [markdown]
# ### Exercise 1: Flexible Positional-Only and Keyword-Only Arguments
# 1. Write a function `format_user(first_name, last_name, /, *, uppercase=False)`.
# 2. The function should return `"LASTNAME, FIRSTNAME"` if `uppercase` is True, otherwise `"Firstname Lastname"`.
# 3. Test calling it correctly, and try calling it incorrectly to verify enforcement rules.

# %%
# Write your code below

# %% [markdown]
# ### Exercise 2: Scope Resolution & State Preservation
# 1. Create a variable `count = 0` globally.
# 2. Write a function `increment()` that increments the global `count`.
# 3. Write a function `outer_counter()` containing a nested function `inner()` that modifies a local enclosing variable `inner_count` using the `nonlocal` keyword.

# %%
# Write your code below

# %% [markdown]
# ### Exercise 3: Lambda sorting
# 1. Take a list of string names: `["Alice", "Bob", "Christopher", "Dave"]`.
# 2. Use the built-in `sorted()` function with a custom `key` argument represented by a `lambda` function to sort the names by their length.

# %%
# Write your code below

# %% [markdown]
# ### Exercise 4: Generator Range Filter
# 1. Write a generator function `even_numbers_generator(limit)` that yields even numbers from 2 up to `limit`.
# 2. Iterate over the generator manually using `next()` twice, then use a `for` loop to print the remaining generated elements.

# %%
# Write your code below

# %% [markdown]
# ### Exercise 5: Closure Factory
# 1. Create a closure generator `power_factory(exponent)`.
# 2. It should return a function that raises any given base to the power of `exponent`.
# 3. Create `square = power_factory(2)` and `cube = power_factory(3)` and test them.

# %%
# Write your code below

# %% [markdown]
# ### Exercise 6: Performance Timer Decorator
# 1. Create a decorator `@time_it` that logs the time a function took to execute.
# 2. Use `time.perf_counter()` from Python's built-in `time` module.
# 3. Decorate a function that calculates a large sum (e.g. sum of range 1 to 1,000,000).

# %%
# Write your code below

# %% [markdown]
# ### Exercise 7: Functional pipeline (map, filter, reduce)
# 1. Take a list of numbers: `[12, 5, 8, 19, 20, 3, 14]`.
# 2. Use `filter()` to select numbers greater than `10`.
# 3. Use `map()` to multiply those numbers by `10`.
# 4. Use `reduce()` to sum them up.

# %%
# Write your code below

# %% [markdown]
# ### Exercise 8: Pythonic Comprehensions Alternative
# Re-write the functional pipeline from Exercise 7 using a single pythonic generator expression or list comprehension and `sum()`.

# %%
# Write your code below
